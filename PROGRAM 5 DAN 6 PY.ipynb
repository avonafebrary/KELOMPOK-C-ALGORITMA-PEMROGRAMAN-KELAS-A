# %% [markdown]
# <a href="https://colab.research.google.com/github/avonafebrary/KELOMPOK-C-ALGORITMA-PEMROGRAMAN-KELAS-A/blob/main/Projek_Alpro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#soal nomor 5
import math

# Fungsi untuk menghitung jarak Euclidean 3 dimensi
def hitung_jarak(titik1, titik2):
    return math.sqrt(
        (titik1[0] - titik2[0]) ** 2 +
        (titik1[1] - titik2[1]) ** 2 +
        (titik1[2] - titik2[2]) ** 2
    )

# Fungsi untuk menentukan cluster
def tentukan_cluster(titik_u):
    cluster_a = (2, 1, 3)
    cluster_b = (1, -4, 6)
    cluster_c = (-2, 3, -2)

    jarak_a = hitung_jarak(titik_u, cluster_a)
    jarak_b = hitung_jarak(titik_u, cluster_b)
    jarak_c = hitung_jarak(titik_u, cluster_c)

    print(f"Jarak ke Cluster A = {jarak_a:.2f}")
    print(f"Jarak ke Cluster B = {jarak_b:.2f}")
    print(f"Jarak ke Cluster C = {jarak_c:.2f}")

    if jarak_a <= jarak_b and jarak_a <= jarak_c:
        return "A"
    elif jarak_b <= jarak_a and jarak_b <= jarak_c:
        return "B"
    else:
        return "C"

# Program utama
x1 = float(input("Masukkan x1: "))
x2 = float(input("Masukkan x2: "))
x3 = float(input("Masukkan x3: "))

titik_u = (x1, x2, x3)

hasil_cluster = tentukan_cluster(titik_u)

print("Titik U termasuk Cluster", hasil_cluster)
# Out:
# Masukkan x1: 3
# Masukkan x2: -2
# Masukkan x3: 6
# Jarak ke Cluster A = 4.36
# Jarak ke Cluster B = 2.83
# Jarak ke Cluster C = 10.68
# Titik U termasuk Cluster B

# %%
#Soal nomor 5 (tidak valid)
import math

def hitung_jarak(titik1, titik2):
    return math.sqrt(
        (titik1[0] - titik2[0]) ** 2 +
        (titik1[1] - titik2[1]) ** 2 +
        (titik1[2] - titik2[2]) ** 2
    )

def tentukan_cluster(titik_u):
    cluster_a = (2, 1, 3)
    cluster_b = (1, -4, 6)
    cluster_c = (-2, 3, -2)

    jarak_a = hitung_jarak(titik_u, cluster_a)
    jarak_b = hitung_jarak(titik_u, cluster_b)
    jarak_c = hitung_jarak(titik_u, cluster_c)

    print(f"Jarak ke Cluster A = {jarak_a:.2f}")
    print(f"Jarak ke Cluster B = {jarak_b:.2f}")
    print(f"Jarak ke Cluster C = {jarak_c:.2f}")

    if jarak_a <= jarak_b and jarak_a <= jarak_c:
        return "A"
    elif jarak_b <= jarak_a and jarak_b <= jarak_c:
        return "B"
    else:
        return "C"

try:
    x1 = float(input("Masukkan x1: "))
    x2 = float(input("Masukkan x2: "))
    x3 = float(input("Masukkan x3: "))

    titik_u = (x1, x2, x3)

    hasil = tentukan_cluster(titik_u)

    print("Titik U termasuk Cluster", hasil)

except ValueError:
    print("Input harus berupa angka!")
# Out:
# Masukkan x1: 1
# Masukkan x2: a
# Input harus berupa angka!

# %%
#Soal Nomor 6
import math

def hitung_interval_kepercayaan(proporsi, n, alpha):

    if proporsi < 0 or proporsi > 1:
        return "Error: Proporsi harus berada antara 0 dan 1."

    if n <= 0:
        return "Error: Ukuran sampel harus lebih dari 0."

    if alpha == 0.10:
        z = 1.645
    elif alpha == 0.05:
        z = 1.96
    else:
        return "Error: Alpha harus 0.05 atau 0.10."

    galat = z * math.sqrt((proporsi * (1 - proporsi)) / n)

    batas_bawah = proporsi - galat
    batas_atas = proporsi + galat

    return batas_bawah, batas_atas

# Program utama
p_hat = float(input("Masukkan proporsi sampel (p̂): "))
n = int(input("Masukkan ukuran sampel (n): "))
alpha = float(input("Masukkan alpha (0.05 atau 0.10): "))

hasil = hitung_interval_kepercayaan(p_hat, n, alpha)

if isinstance(hasil, str):
    print(hasil)
else:
    print(f"Interval Kepercayaan: ({hasil[0]:.4f}, {hasil[1]:.4f})")
# Out:
# Masukkan proporsi sampel (p̂): 1
# Masukkan ukuran sampel (n): 50
# Masukkan alpha (0.05 atau 0.10): 0.05
# Interval Kepercayaan: (1.0000, 1.0000)

# %%
#Soal Nomor 6 (tidak valid)
import math

def hitung_interval_kepercayaan(proporsi, n, alpha):

    if proporsi < 0 or proporsi > 1:
        return "Error: Proporsi harus berada antara 0 dan 1."

    if n <= 0:
        return "Error: Ukuran sampel harus lebih dari 0."

    if alpha == 0.10:
        z = 1.645
    elif alpha == 0.05:
        z = 1.96
    else:
        return "Error: Alpha harus 0.05 atau 0.10."

    galat = z * math.sqrt((proporsi * (1 - proporsi)) / n)

    batas_bawah = proporsi - galat
    batas_atas = proporsi + galat

    return batas_bawah, batas_atas

# Program utama
p_hat = float(input("Masukkan proporsi sampel (p̂): "))
n = int(input("Masukkan ukuran sampel (n): "))
alpha = float(input("Masukkan alpha (0.05 atau 0.10): "))

hasil = hitung_interval_kepercayaan(p_hat, n, alpha)

if isinstance(hasil, str):
    print(hasil)
else:
    print(f"Interval Kepercayaan: ({hasil[0]:.4f}, {hasil[1]:.4f})")
# Out:
# Masukkan proporsi sampel (p̂): 3
# Masukkan ukuran sampel (n): 300
# Masukkan alpha (0.05 atau 0.10): 0.05
# Error: Proporsi harus berada antara 0 dan 1.

# %%
import math

def hitung_interval_kepercayaan(proporsi, n, alpha):

    if proporsi < 0 or proporsi > 1:
        return "Error: Proporsi harus berada antara 0 dan 1."

    if n <= 0:
        return "Error: Ukuran sampel harus lebih dari 0."

    if alpha == 0.10:
        z = 1.645
    elif alpha == 0.05:
        z = 1.96
    else:
        return "Error: Alpha harus 0.05 atau 0.10."

    galat = z * math.sqrt((proporsi * (1 - proporsi)) / n)

    batas_bawah = proporsi - galat
    batas_atas = proporsi + galat

    return batas_bawah, batas_atas

# Program utama
p_hat = float(input("Masukkan proporsi sampel (p̂): "))
n = int(input("Masukkan ukuran sampel (n): "))
alpha = float(input("Masukkan alpha (0.05 atau 0.10): "))

hasil = hitung_interval_kepercayaan(p_hat, n, alpha)

if isinstance(hasil, str):
    print(hasil)
else:
    print(f"Interval Kepercayaan: ({hasil[0]:.4f}, {hasil[1]:.4f})")
# Out:
# Masukkan proporsi sampel (p̂): 2
# Masukkan ukuran sampel (n): 34
# Masukkan alpha (0.05 atau 0.10): 0.05
# Error: Proporsi harus berada antara 0 dan 1.
